# %% [markdown]
# # 媒体融合策略与效果分析
#
# 2020-12-10 14:40:08

# %%
import pandas as pd
import seaborn as sns

# %%
ls
# Out:
# LICENSE                           media-convergence-research.ipynb
# README.md                         数据fillna.xlsx

# %%
df = pd.read_excel('数据fillna.xlsx')
df.head()
# Out:
#    Unnamed: 0        媒体  规模  类型  地理位置  所有制  资本策略  基础设施  接入渠道策略  第三方合作策略  ...  \
# 0           0   周口广播电视台   3   2     4    1     0     1       1        1  ...
# 1           1  《中国肿瘤临床》   1   4     1    2     0     0       1        0  ...
# 2           2  江西报业传媒集团   2   1     3    2     1     1       1        1  ...
# 3           3   四川合江县广电   3   2     5    1     0     0       1        1  ...
# 4           4      池州日报   3   1     3    1     0     1       1        0  ...
#
#    技术融合策略  市场策略  内容策略  报告效果年份  是否报告粉丝量  是否报告下载量/点击量/发行量  是否报告营收  效果强度：粉丝量  \
# 0       1     1     1    2015        0                0       0         0
# 1       0     0     1    2016        0                0       0         0
# 2       1     0     1    2007        0                1       0         0
# 3       0     1     1    2018        0                0       0         0
# 4       1     1     1    2018        0                0       0         0
#
#    效果强度：下载量/点击量/发行量  效果强度：营收
# 0                 0        0
# 1                 0        0
# 2                 2        0
# 3                 0        0
# 4                 0        0
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (163, 24)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '媒体', '规模', '类型', '地理位置', '所有制', '资本策略', '基础设施', '接入渠道策略',
#        '第三方合作策略', '组织融合', '人才策略', '经营管理策略', '政治帮扶', '技术融合策略', '市场策略', '内容策略',
#        '报告效果年份', '是否报告粉丝量', '是否报告下载量/点击量/发行量', '是否报告营收', '效果强度：粉丝量',
#        '效果强度：下载量/点击量/发行量', '效果强度：营收'],
#       dtype='object')

# %% [markdown]
# ## 编码表
#
# | 媒体                | 属性                            |                                                              |                     |
# | ------------------- | ------------------------------- | ------------------------------------------------------------ | ------------------- |
# | 层级                | 媒体类型                        | 地理位置                                                     | 所有制              |
# | 1-中央  2-省 3-市县 | 1-报纸 2-广播电视 3-网络 4-出版 | 1-华北 2-东北 3-华东 4-华中 5-西南 6-西北  7-华南 8-港澳台地区 9-未知/其他 | 1-公有制 2-非公有制 |
#
# | 策略∈{1,0}                     |                            |                       |                      |                                     |                                            |                                                          |          |                                      |                                                              |                                           |
# | ------------------------------ | -------------------------- | --------------------- | -------------------- | ----------------------------------- | ------------------------------------------ | -------------------------------------------------------- | -------- | ------------------------------------ | ------------------------------------------------------------ | ----------------------------------------- |
# | 资本策略                       | 基础设施                   | 接入渠道策略          | 第三方合作策略       | 组织融合                            | 人才策略                                   | 经营管理策略                                             | 政治帮扶 | 技术融合策略                         | 市场策略                                                     | 内容策略                                  |
# | 投资、挂牌证券系统、融资、众筹 | 云平台、数据平台、中央厨房 | 自建APP、入驻微信微博 | 与公司、其他媒体合作 | 合并广电纸媒宣传部门等形成集团/公司 | 高新聘请人才、与高校签约引进人才、职员培训 | 所有制改革、股权结构改革，员工激励政策（股份）、开设公司 | 结对子   | AI写作，无人机、VRAR、提到技术融合的 | 建立品牌效应，面向下沉市场，投放大屏，投放广告做宣传，针对不同人群 | 提升内容质量、版面效果、政务信息+内容服务 |
#
# | 报告效果年份(没有效果的按论文发表年份） | 是否报告效果         | 效果强度          |                |                      |                |
# | --------------------------------------- | -------------------- | ----------------- | -------------- | -------------------- | -------------- |
# | 粉丝量                                  | 下载量/点击量/发行量 | 营收              | 粉丝量         | 下载量/点击量/发行量 | 营收           |
# | 1-有效果  0-无效果                      | 1-有效果 0-无效果    | 1-有效果 0-无效果 | 2-强 1-弱 0-无 | 2-强 1-弱 0-无       | 2-强 1-弱 0-无 |

# %%
df.describe()
# Out:
#        Unnamed: 0          规模          类型        地理位置         所有制        资本策略  \
# count  163.000000  163.000000  163.000000  163.000000  163.000000  163.000000
# mean    81.000000    2.319018    1.926380    3.539877    1.269939    0.110429
# std     47.198164    0.751176    0.939913    2.058543    0.445296    0.314390
# min      0.000000    1.000000    1.000000    1.000000    1.000000    0.000000
# 25%     40.500000    2.000000    1.000000    1.500000    1.000000    0.000000
# 50%     81.000000    2.000000    2.000000    3.000000    1.000000    0.000000
# 75%    121.500000    3.000000    2.000000    5.000000    2.000000    0.000000
# max    162.000000    3.000000    4.000000    9.000000    2.000000    1.000000
#
#              基础设施      接入渠道策略     第三方合作策略        组织融合  ...      技术融合策略  \
# count  163.000000  163.000000  163.000000  163.000000  ...  163.000000
# mean     0.478528    0.993865    0.392638    0.226994  ...    0.343558
# std      0.501078    0.078326    0.489842    0.420179  ...    0.476359
# min      0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 25%      0.000000    1.000000    0.000000    0.000000  ...    0.000000
# 50%      0.000000    1.000000    0.000000    0.000000  ...    0.000000
# 75%      1.000000    1.000000    1.000000    0.000000  ...    1.000000
# max      1.000000    1.000000    1.000000    1.000000  ...    1.000000
#
#              市场策略        内容策略       报告效果年份     是否报告粉丝量  是否报告下载量/点击量/发行量  \
# count  163.000000  163.000000   163.000000  163.000000       163.000000
# mean     0.693252    0.840491  2016.699387    0.331288         0.288344
# std      0.462565    0.367279     2.293671    0.472127         0.454388
# min      0.000000    0.000000  2007.000000    0.000000         0.000000
# 25%      0.000000    1.000000  2016.000000    0.000000         0.000000
# 50%      1.000000    1.000000  2017.000000    0.000000         0.000000
# 75%      1.000000    1.000000  2018.000000    1.000000         1.000000
# max      1.000000    1.000000  2020.000000    1.000000         1.000000
#
#            是否报告营收    效果强度：粉丝量  效果强度：下载量/点击量/发行量     效果强度：营收
# count  163.000000  163.000000        163.000000  163.000000
# mean     0.147239    0.392638          0.392638    0.226994
# std      0.355436    0.602829          0.661420    0.580555
# min      0.000000    0.000000          0.000000    0.000000
# 25%      0.000000    0.000000          0.000000    0.000000
# 50%      0.000000    0.000000          0.000000    0.000000
# 75%      0.000000    1.000000          1.000000    0.000000
# max      1.000000    2.000000          2.000000    2.000000
#
# [8 rows x 23 columns]

# %% [markdown]
# ## 透视表(pivotTab)
# 透视表就是将指定原有DataFrame的列分别作为行索引和列索引，然后对指定的列应用聚集函数(默认情况下式mean函数)。
#
# ## 列联表（crossTab）
# 交叉表是用于统计分组频率的特殊透视表

# %%
pd.crosstab(df['规模'],df['类型'],margins=True)
# Out:
# 类型    1   2  3   4  All
# 规模
# 1    10   4  0  14   28
# 2    24  27  1   3   55
# 3    23  51  2   4   80
# All  57  82  3  21  163

# %%
pd.crosstab(df['规模'],df['类型'],margins=True, normalize='index')
# Out:
# 类型          1         2         3         4
# 规模
# 1    0.357143  0.142857  0.000000  0.500000
# 2    0.436364  0.490909  0.018182  0.054545
# 3    0.287500  0.637500  0.025000  0.050000
# All  0.349693  0.503067  0.018405  0.128834

# %%
df[['人才策略','规模','类型']].pivot_table(index=['规模','类型'])
# Out:
#            人才策略
# 规模 类型
# 1  1   0.400000
#    2   0.000000
#    4   0.357143
# 2  1   0.291667
#    2   0.111111
#    3   1.000000
#    4   0.000000
# 3  1   0.260870
#    2   0.450980
#    3   0.500000
#    4   0.250000

# %%
df[['资本策略', '基础设施', '接入渠道策略',
    '第三方合作策略', '组织融合', '人才策略',
    '经营管理策略', '政治帮扶', '技术融合策略',
    '市场策略', '内容策略','规模']].pivot_table(index=['规模'])
# Out:
#         人才策略      内容策略      基础设施      市场策略    技术融合策略    接入渠道策略   政治帮扶  \
# 规模
# 1   0.321429  0.821429  0.392857  0.678571  0.392857  1.000000  0.000
# 2   0.200000  0.781818  0.454545  0.690909  0.345455  0.981818  0.000
# 3   0.387500  0.887500  0.525000  0.700000  0.325000  1.000000  0.025
#
#      第三方合作策略      组织融合    经营管理策略      资本策略
# 规模
# 1   0.321429  0.107143  0.464286  0.107143
# 2   0.400000  0.272727  0.345455  0.163636
# 3   0.412500  0.237500  0.287500  0.075000

# %% [markdown]
# ## 可视化列联表与相似性矩阵

# %%
# Draw the full plot
data = df[['资本策略', '基础设施', '接入渠道策略',
    '第三方合作策略', '组织融合', '人才策略',
    '经营管理策略', '政治帮扶', '技术融合策略',
    '市场策略', '内容策略','规模']].pivot_table(index=['规模']).T

sns.set(style='whitegrid', font ='simhei', font_scale= 2)
sns.clustermap(data, 
               center=0, cmap="vlag",
               #row_colors=network_colors, col_colors=network_colors,
               linewidths=.75, figsize=(13, 13));

# %%
# Draw the full plot
data = df[['资本策略', '基础设施', '接入渠道策略',
    '第三方合作策略', '组织融合', '人才策略',
    '经营管理策略', '政治帮扶', '技术融合策略',
    '市场策略', '内容策略','类型']].pivot_table(index=['类型']).T

sns.set(style='whitegrid', font ='simhei', font_scale= 2)
sns.clustermap(data, 
               center=0, cmap="vlag",
               #row_colors=network_colors, col_colors=network_colors,
               linewidths=.75, figsize=(13, 13));

# %%
# Draw the full plot
data = df[['资本策略', '基础设施', '接入渠道策略',
    '第三方合作策略', '组织融合', '人才策略',
    '经营管理策略', '政治帮扶', '技术融合策略',
    '市场策略', '内容策略','所有制']].pivot_table(index=['所有制']).T

sns.set(style='whitegrid', font ='simhei', font_scale= 2)
sns.clustermap(data, 
               center=0, cmap="vlag",
               #row_colors=network_colors, col_colors=network_colors,
               linewidths=.75, figsize=(13, 13));

# %%
# Draw the full plot
from scipy.spatial.distance import squareform
from scipy.spatial.distance import pdist, jaccard

colnames = ['资本策略', '基础设施', '接入渠道策略',
    '第三方合作策略', '组织融合', '人才策略',
    '经营管理策略', '政治帮扶', '技术融合策略',
    '市场策略', '内容策略']
sim = 1 - pdist(df[colnames].T, 'jaccard')
df_sim = pd.DataFrame(squareform(sim), index = colnames, columns = colnames)

sns.set(style='whitegrid', font ='simhei', font_scale= 2)
sns.clustermap(df_sim, 
               center=0, cmap="vlag",
               #row_colors=network_colors, col_colors=network_colors,
               linewidths=.75, figsize=(13, 13));

# %%
df_sim
# Out:
#              资本策略      基础设施    接入渠道策略   第三方合作策略      组织融合      人才策略    经营管理策略  \
# 资本策略     0.000000  0.103448  0.111111  0.171429  0.170213  0.150000  0.216667
# 基础设施     0.103448  0.000000  0.481481  0.290909  0.277778  0.277228  0.266667
# 接入渠道策略   0.111111  0.481481  0.000000  0.386503  0.220859  0.314815  0.339506
# 第三方合作策略  0.171429  0.290909  0.386503  0.000000  0.188235  0.236559  0.279570
# 组织融合     0.170213  0.277778  0.220859  0.188235  0.000000  0.257143  0.243243
# 人才策略     0.150000  0.277228  0.314815  0.236559  0.257143  0.000000  0.247059
# 经营管理策略   0.216667  0.266667  0.339506  0.279570  0.243243  0.247059  0.000000
# 政治帮扶     0.000000  0.000000  0.012346  0.015385  0.026316  0.000000  0.000000
# 技术融合策略   0.138462  0.440860  0.345679  0.290323  0.240000  0.289157  0.121212
# 市场策略     0.100840  0.394161  0.687117  0.361538  0.200000  0.291339  0.312500
# 内容策略     0.107143  0.472603  0.834356  0.395833  0.216783  0.352518  0.342657
#
#              政治帮扶    技术融合策略      市场策略      内容策略
# 资本策略     0.000000  0.138462  0.100840  0.107143
# 基础设施     0.000000  0.440860  0.394161  0.472603
# 接入渠道策略   0.012346  0.345679  0.687117  0.834356
# 第三方合作策略  0.015385  0.290323  0.361538  0.395833
# 组织融合     0.026316  0.240000  0.200000  0.216783
# 人才策略     0.000000  0.289157  0.291339  0.352518
# 经营管理策略   0.000000  0.121212  0.312500  0.342657
# 政治帮扶     0.000000  0.000000  0.008772  0.007246
# 技术融合策略   0.000000  0.000000  0.373984  0.349650
# 市场策略     0.008772  0.373984  0.000000  0.712329
# 内容策略     0.007246  0.349650  0.712329  0.000000

# %%
df1 = pd.DataFrame([['a', 'x', 'a'], 
                   ['b', 'z', 'a'], 
                   ['a', 'x', 'a']], 
                  columns=['v1', 'v2', 'v3'], 
                  index=['r1', 'r2', 'r3'])

df1
# Out:
#    v1 v2 v3
# r1  a  x  a
# r2  b  z  a
# r3  a  x  a

# %%
from itertools import combinations
from scipy.stats import chi2_contingency

def get_corr_mat(df, f=chi2_contingency):
    columns = df.columns
    dm = pd.DataFrame(index=columns, columns=columns)
    for var1, var2 in combinations(columns, 2):
        cont_table = pd.crosstab(df[var1], df[var2], margins=False)
        chi2_stat = f(cont_table)[0]
        dm.loc[var2, var1] = chi2_stat
        dm.loc[var1, var2] = chi2_stat
    dm.fillna(0, inplace=True)
    return dm

get_corr_mat(df1)
# Out:
#         v1      v2   v3
# v1  0.0000  0.1875  0.0
# v2  0.1875  0.0000  0.0
# v3  0.0000  0.0000  0.0

# %%
colnames = ['资本策略', '基础设施', '接入渠道策略',
    '第三方合作策略', '组织融合', '人才策略',
    '经营管理策略', '政治帮扶', '技术融合策略',
    '市场策略', '内容策略']
df_sim = get_corr_mat(df[colnames])

sns.set(style='whitegrid', font ='simhei', font_scale= 2)
sns.clustermap(df_sim, 
               center=0, cmap="vlag",
               #row_colors=network_colors, col_colors=network_colors,
               linewidths=.75, figsize=(13, 13));
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py:595: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   metric=self.metric)

# %% [markdown]
# ## 统计分析

# %%
colnames = ['资本策略', '基础设施', '接入渠道策略',
    '第三方合作策略', '组织融合', '人才策略',
    '经营管理策略', '政治帮扶', '技术融合策略',
    '市场策略', '内容策略']

for cname in colnames:
    for rname in ['规模', '类型', '地理位置', '所有制']:
        data = pd.crosstab(df[rname],df[cname],margins=False)
        chi2, p, ddof, expected = chi2_contingency( data )
        if p <=0.05:
            print(rname, cname, chi2, p)
# Out:
# 类型 基础设施 14.61961856135759 0.0021723277138810705
# 地理位置 政治帮扶 29.22986071899115 0.0002889491964513108
# 类型 技术融合策略 9.02086165318046 0.029014801491923568

# %%
colnames = ['是否报告粉丝量', '是否报告下载量/点击量/发行量', '是否报告营收', '效果强度：粉丝量',
       '效果强度：下载量/点击量/发行量', '效果强度：营收']

for cname in colnames:
    for rname in ['规模', '类型', '地理位置', '所有制']:
        data = pd.crosstab(df[rname],df[cname],margins=False)
        chi2, p, ddof, expected = chi2_contingency( data )
        if p <=0.05:
            print(rname, cname, chi2, p)
# Out:
# 规模 效果强度：粉丝量 11.226910134798478 0.024128806857318667
# 规模 效果强度：下载量/点击量/发行量 11.751764451581028 0.019295907219614404

# %% [markdown]
# ## 链接分析
#
# The HITS algorithm computes two numbers for a node. Authorities estimates the node value based on the incoming links. Hubs estimates the node value based on outgoing links.

# %%
colnames = ['媒体','资本策略', '基础设施', '接入渠道策略',
    '第三方合作策略', '组织融合', '人才策略',
    '经营管理策略', '政治帮扶', '技术融合策略',
    '市场策略', '内容策略']

mat = df[colnames]

edges = []
for i in mat.index:
    for j in colnames:
        if df[j].iloc[i] ==1:
            edges.append([df['媒体'].iloc[i], j])

# %%
edges[:3]
# Out:
# [['周口广播电视台', '基础设施'], ['周口广播电视台', '接入渠道策略'], ['周口广播电视台', '第三方合作策略']]

# %%
import networkx as nx


B = nx.Graph()
users, items = {i for i, j in edges}, {j for i, j in edges}
for i, j in edges:
    B.add_edge(i,j)
h, a = nx.hits(B) 

print({i:a[i] for i in items} )
# Out:
# {'人才策略': 0.03530382719343313, '技术融合策略': 0.039353550347734655, '资本策略': 0.01243953953376327, '接入渠道策略': 0.09521312830932586, '政治帮扶': 0.0008101516708092756, '市场策略': 0.07363999032213624, '组织融合': 0.025020350029683218, '第三方合作策略': 0.042708929829838524, '经营管理策略': 0.03631770393393784, '基础设施': 0.052452497194322635, '内容策略': 0.08674033163501574}

# %%
print({i:h[i] for i in users} )
# Out:
# {'河南广播电台': 0.007412257745610913, '成都音像出版社': 0.007891385672261482, '重庆地方电视民生新闻节目': 0.004051313651365958, '《劳动保护》': 0.0018232865928190826, '淮南市广播电视台': 0.0034843231172467172, '安徽省濉溪县': 0.005898934904783676, '宁夏青铜峡': 0.005898934904783676, '《新法制报》': 0.00430217902152298, 'A省Q县': 0.006002086591340299, '苏州广电': 0.007470392775542404, '中央电视台': 0.0066525368712661405, '《无人系统技术》': 0.005589961208068304, '山西工人报社': 0.0048944942715173296, '万州电视台': 0.003987059713572161, '曲靖日报社': 0.005712350175793592, '玉门广播电视台': 0.007470392775542404, 'A县广播电视台': 0.007470392775542404, '山东广播电台': 0.0039289246836406696, '《植物学报》': 0.005712350175793592, '都江堰电视台': 0.0018232865928190826, '深圳晚报报业集团': 0.006646028439453458, '江苏电视台': 0.007470392775542404, '浙江大学学报': 0.006465952142276058, '东方早报-澎湃新闻': 0.006098493688348236, '《战术导弹技术》': 0.0064078171123445665, '深圳广播电台': 0.005898934904783676, '漾濞县融媒体中心': 0.0067362732954471, '四川合江县广电': 0.0064078171123445665, '江西省分宜县': 0.005860282361239346, '《体育周报》': 0.005570545945692639, '凉山彝族自治州': 0.005898934904783676, '金堂电视台': 0.0057318326621807565, '青岛报业集团': 0.009559250640028147, '《高等学校化学学报》': 0.005589961208068304, '淮北日报': 0.007562996713170447, '滕州县': 0.006397545317821408, '长兴广电': 0.008805648673545682, '人民日报': 0.00616609521004005, '永川广播电视台': 0.007270453515509959, '湖南广播电台': 0.005886307565108686, '《新周刊》': 0.0048944942715173296, '南方报业传媒集团': 0.006397545317821408, '新华社': 0.007827131734467686, '新京报': 0.004418001380906582, 'A省N县': 0.002656656520274351, '陕西日报': 0.005570545945692639, '瑞安日报社': 0.005712350175793592, '北京广播电视台': 0.006427272895358587, 'A市7个区县的县级融媒体中心': 0.0033068551527359966, '贵州日报': 0.006886945038995138, '黄冈广电': 0.006324147912175104, '西安电视台': 0.004488763750513062, '东广新闻台（广播）': 0.005712350175793592, '镇海县广电': 0.005898934904783676, 'B省Y县': 0.006002086591340299, '邢台日报社': 0.0066525368712661405, '（SaaS）天津“津云”中央厨房-天津北方网新媒体集团\xa0': 0.008165859712093378, '华龙网集团-重庆（一个私营企业承包了一个省的媒体融合任务\xa01+39）': 0.007470392775542404, '天津广播电台': 0.00430217902152298, '江西F县': 0.006339410287889915, '拉萨市融媒体中心': 0.007392842483235247, '中国国际广播电台': 0.008404071039202269, '《建筑学报》': 0.006266012882243614, '湖南日报': 0.0018232865928190826, '浙江广播电台': 0.0039289246836406696, '（SaaS）中国广播云平台\xa0': 0.007470392775542404, '成都日报社': 0.00497823069569829, '河北广电': 0.005648096237999795, '赤壁市广播电视台': 0.002997881456020626, '涪陵广播电视台': 0.005570545945692639, 'J市广播电视台': 0.005570545945692639, '宣城广电': 0.007392842483235247, '百色靖西融媒体中心': 0.005898934904783676, 'ZRZY 报社': 0.004855841727973002, '江西日报社': 0.006378062831434243, '《内蒙古日报》': 0.005242365716995528, '中国国家地理': 0.007083868786519877, '广东广播电台': 0.005043126944957313, '廊坊广播电视台': 0.008841911386268686, '人民出版社\xa0': 0.0064078171123445665, '项城广电': 0.004727365325541267, '光明日报': 0.0028277272260854272, '河北日报': 0.006002086591340299, '清远广播电视台': 0.008554810006761804, '《中国机械工程》': 0.005589961208068304, '羊城晚报报业集团': 0.00430217902152298, '湖南广电媒体': 0.007380215143560259, '湖北日报传媒集团': 0.002540625846578541, '中央人民广播电台中国之声': 0.0018232865928190826, '贵州电视台': 0.006886945038995138, '蚌埠电视台': 0.0034843231172467172, '吉林广电': 0.004878313023494726, '中央社': 0.0051842306870640365, '《联合报》': 0.008024055481992424, '重庆晨报': 0.006391036886008724, '吉林人民广播电台': 0.005898934904783676, '中国日报社': 0.004399185096844156, '郑州报业': 0.005785747581439894, '辽宁出版集团': 0.002997881456020626, '洛阳日报报业集团': 0.006266012882243614, '《航空知识》': 0.00659440184133465, '荆州日报传媒集团': 0.005389136221346906, '邳州广电': 0.005712350175793592, '北仑县广电': 0.004488763750513062, '秦皇岛融媒体中心': 0.0042378983803560396, '浙江日报报业集团': 0.0038195405196767827, '《儿童文学》': 0.0048944942715173296, '（SaaS+C）成都市广播电视台': 0.009080122713377579, '江南都市报': 0.005589961208068304, '奉化县广电': 0.00430217902152298, '宁海县广电': 0.0048944942715173296, '绍兴市广播电视台': 0.006397545317821408, '广东珠江经济台（广播）': 0.007650469072719801, '南方周末': 0.007949520702192974, '周口广播电视台': 0.009321039312919258, '婺城区新闻传媒中心': 0.0066525368712661405, '秦皇岛日报社': 0.0028277272260854272, '四川日报社': 0.007470392775542404, '山东广播电视台': 0.007073529767985217, '《物理学报》': 0.00430217902152298, 'LS 报社': 0.0034843231172467172, '《少年先锋报》': 0.00489 ...

# %%
nx.draw(B)

# %%
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline
import networkx.algorithms.community as nxcom
import random
from numpy import random as nprand
random.seed(123)
nprand.seed(123)

plt.rcParams.update(plt.rcParamsDefault)
plt.rcParams.update({'figure.figsize': (15, 15)})

plt.style.use('fivethirtyeight')
plt.rcParams['font.family'] = ['sans-serif']
plt.rcParams['font.sans-serif'] = ['SimHei']

# %%
def set_node_community(G, communities):
        '''Add community to node attributes'''
        for c, v_c in enumerate(communities):
            for v in v_c:
                # Add 1 to save 0 for external edges
                G.nodes[v]['community'] = c + 1

def set_edge_community(G):
    '''Find internal edges and add their community to their attributes'''
    for v, w, in G.edges:
        if G.nodes[v]['community'] == G.nodes[w]['community']:
            # Internal edge, mark with community
            G.edges[v, w]['community'] = G.nodes[v]['community']
        else:
            # External edge, mark as 0
            G.edges[v, w]['community'] = 0

def get_color(i, r_off=1, g_off=1, b_off=1):
    '''Assign a color to a vertex.'''
    r0, g0, b0 = 0, 0, 0
    n = 16
    low, high = 0.1, 0.9
    span = high - low
    r = low + span * (((i + r_off) * 3) % n) / (n - 1)
    g = low + span * (((i + g_off) * 5) % n) / (n - 1)
    b = low + span * (((i + b_off) * 7) % n) / (n - 1)
    return (r, g, b)

# %%
pos = nx.spring_layout(B, k=0.1)
plt.rcParams.update({'figure.figsize': (15, 15)})
nx.draw_networkx( B, pos=pos, node_size=30, edge_color="#444444", 
                 alpha=0.05, with_labels=True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 160 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 160 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
communities = sorted(nxcom.greedy_modularity_communities(B), key=len, reverse=True)
len(communities)
# Out:
# 6

# %%
# PLOT
plt.rcParams.update(plt.rcParamsDefault)
plt.rcParams.update({'figure.figsize': (15, 15)})
plt.rcParams['font.family'] = ['sans-serif']
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.style.use('dark_background')

# Set node and edge communities
set_node_community(B, communities)
set_edge_community(B)

# Set community color for internal edges
external = [(v, w) for v, w in B.edges if B.edges[v, w]['community'] == 0]
internal = [(v, w) for v, w in B.edges if B.edges[v, w]['community'] > 0]
internal_color = ["black" for e in internal]
node_color = [get_color(B.nodes[v]['community']) for v in B.nodes]
# external edges
nx.draw_networkx(
    B, 
    pos=pos, 
    node_size=30, 
    edgelist=external, 
    edge_color="silver",
    node_color=node_color,
    alpha=0.2, 
    with_labels=False)
# internal edges
nx.draw_networkx(
    B, pos=pos, 
    edgelist=internal, 
    edge_color=internal_color,
    node_color=node_color,
    alpha=0.05, 
    with_labels=False)
